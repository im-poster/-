# %%
import pandas as pd
import csv
import time
import matplotlib.pyplot as plt

# %%
test = pd.read_csv("levelsmap_concat.csv")
#轉時間
test['start_date_new']=test['startTimeInSeconds'].apply(
    lambda x: time.strftime("%Y-%m-%d %H:%M:%S",time.localtime(x+8*3600)) if not(pd.isnull(x)) else x)
test['end_date_new']=test['endTimeInSeconds'].apply(
    lambda x: time.strftime("%Y-%m-%d %H:%M:%S",time.localtime(x+8*3600)) if not(pd.isnull(x)) else x)
test["new_id"]=test["id"].apply(lambda x:x.replace("levelsmap_",""))
test = test.sort_values(by=['new_id','start_date_new'])
test

#選定一個人和時間，看時間是否對齊
# id1 = test[test['new_id']=='1091_uty_1']
# id1 = id1[id1['date']==1017.0]
# id1.sort_values(by=['start_date_new'])
# Out:
#          date  endTimeInSeconds                    id sleepLevels  \
# 11075   927.0        1601158980   1091_mr_levelsmap_1       light
# 11096   928.0        1601158980   1091_mr_levelsmap_1       light
# 11135   930.0        1601158980   1091_mr_levelsmap_1       light
# 11069   927.0        1601160120   1091_mr_levelsmap_1        deep
# 11090   928.0        1601160120   1091_mr_levelsmap_1        deep
# ...       ...               ...                   ...         ...
# 112112    NaN        1653699840  1102_mrw_levelsmap_9         rem
# 112148    NaN        1653699840  1102_mrw_levelsmap_9         rem
# 112139    NaN        1653700800  1102_mrw_levelsmap_9       awake
# 112131    NaN        1653701400  1102_mrw_levelsmap_9       light
# 112149    NaN        1653703320  1102_mrw_levelsmap_9         rem
#
#         startTimeInSeconds               summaryId       start_date_new  \
# 11075           1601157000  x339afaf-5f6fb788-6180  2020-09-27 13:50:00
# 11096           1601157000  x339afaf-5f6fb788-6180  2020-09-27 13:50:00
# 11135           1601157000  x339afaf-5f6fb788-6180  2020-09-27 13:50:00
# 11069           1601158980  x339afaf-5f6fb788-6180  2020-09-27 14:23:00
# 11090           1601158980  x339afaf-5f6fb788-6180  2020-09-27 14:23:00
# ...                    ...                     ...                  ...
# 112112          1653698880  x46bc4c4-6291096c-66a8  2022-05-28 16:48:00
# 112148          1653698880  x46bc4c4-6291096c-7080  2022-05-28 16:48:00
# 112139          1653699840  x46bc4c4-6291096c-7080  2022-05-28 17:04:00
# 112131          1653700800  x46bc4c4-6291096c-7080  2022-05-28 17:20:00
# 112149          1653701400  x46bc4c4-6291096c-7080  2022-05-28 17:30:00
#
#                end_date_new      new_id
# 11075   2020-09-27 14:23:00   1091_mr_1
# 11096   2020-09-27 14:23:00   1091_mr_1
# 11135   2020-09-27 14:23:00   1091_mr_1
# 11069   2020-09-27 14:42:00   1091_mr_1
# 11090   2020-09-27 14:42:00   1091_mr_1
# ...                     ...         ...
# 112112  2022-05-28 17:04:00  1102_mrw_9
# 112148  2022-05-28 17:04:00  1102_mrw_9
# 112139  2022-05-28 17:20:00  1102_mrw_9
# 112131  2022-05-28 17:30:00  1102_mrw_9
# 112149  2022-05-28 18:02:00  1102_mrw_9
#
# [119568 rows x 9 columns]

# %%
#刪掉重複值
data = test.drop_duplicates(subset=['start_date_new','new_id'],keep="first").copy()
data
# Out:
#          date  endTimeInSeconds                    id sleepLevels  \
# 11075   927.0        1601158980   1091_mr_levelsmap_1       light
# 11069   927.0        1601160120   1091_mr_levelsmap_1        deep
# 11076   927.0        1601162400   1091_mr_levelsmap_1       light
# 11070   927.0        1601163420   1091_mr_levelsmap_1        deep
# 11077   927.0        1601166180   1091_mr_levelsmap_1       light
# ...       ...               ...                   ...         ...
# 112096    NaN        1653698880  1102_mrw_levelsmap_9       light
# 112112    NaN        1653699840  1102_mrw_levelsmap_9         rem
# 112139    NaN        1653700800  1102_mrw_levelsmap_9       awake
# 112131    NaN        1653701400  1102_mrw_levelsmap_9       light
# 112149    NaN        1653703320  1102_mrw_levelsmap_9         rem
#
#         startTimeInSeconds               summaryId       start_date_new  \
# 11075           1601157000  x339afaf-5f6fb788-6180  2020-09-27 13:50:00
# 11069           1601158980  x339afaf-5f6fb788-6180  2020-09-27 14:23:00
# 11076           1601160120  x339afaf-5f6fb788-6180  2020-09-27 14:42:00
# 11070           1601162400  x339afaf-5f6fb788-6180  2020-09-27 15:20:00
# 11077           1601163420  x339afaf-5f6fb788-6180  2020-09-27 15:37:00
# ...                    ...                     ...                  ...
# 112096          1653698400  x46bc4c4-6291096c-66a8  2022-05-28 16:40:00
# 112112          1653698880  x46bc4c4-6291096c-66a8  2022-05-28 16:48:00
# 112139          1653699840  x46bc4c4-6291096c-7080  2022-05-28 17:04:00
# 112131          1653700800  x46bc4c4-6291096c-7080  2022-05-28 17:20:00
# 112149          1653701400  x46bc4c4-6291096c-7080  2022-05-28 17:30:00
#
#                end_date_new      new_id
# 11075   2020-09-27 14:23:00   1091_mr_1
# 11069   2020-09-27 14:42:00   1091_mr_1
# 11076   2020-09-27 15:20:00   1091_mr_1
# 11070   2020-09-27 15:37:00   1091_mr_1
# 11077   2020-09-27 16:23:00   1091_mr_1
# ...                     ...         ...
# 112096  2022-05-28 16:48:00  1102_mrw_9
# 112112  2022-05-28 17:04:00  1102_mrw_9
# 112139  2022-05-28 17:20:00  1102_mrw_9
# 112131  2022-05-28 17:30:00  1102_mrw_9
# 112149  2022-05-28 18:02:00  1102_mrw_9
#
# [74063 rows x 9 columns]

# %%
#不要hr,min
import re
data['date_new']=data['start_date_new'].apply(
    lambda x: re.search('\d{4}\-\d{2}\-\d{2}',x).group())

# %%
#算出持續時間
data['last_time'] = data['endTimeInSeconds']-data['startTimeInSeconds']

# %%
#建立一個list，用來判斷是否為睡眠開始
data['start or end'] = None

# %%
#判斷是否為開始
l = ['start']
for i in range(1,74063):  
    if data.iloc[i]['start_date_new'] != data.iloc[i-1]['end_date_new']:
        l.append('start')
    else:
        l.append('')
l
# Out:
# ['start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  '',
#  '',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  '',
#  '',
#  'start',
#  'start',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  'start',
#  'start',
#  '',
#  '',
#  'start',
#  ...]

# %%
print(len(l))
# Out:
# 74063

# %%
#把list放進dataframe
data['start or end'] = l

# %%
print(sum(data['start or end']=="start"))
data['start or end']
# Out:
# 31672
# 11075     start
# 11069
# 11076
# 11070
# 11077
#           ...
# 112096
# 112112
# 112139
# 112131
# 112149
# Name: start or end, Length: 74063, dtype: object

# %%
#epochs處理
epochs = pd.read_csv("epochs_concat.csv")
epochs['date_new']=epochs['startTimeInSeconds'].apply(
    lambda x: time.strftime("%Y-%m-%d %H:%M:%S",time.localtime(x+8*3600)) if not(pd.isnull(x)) else x) #日期換算 時區
#epochs
epochs.dropna(axis=0,how='all',subset=['date_new'],inplace=True)
epochs["new_id"]=epochs["id"].apply(lambda x:x.replace("epochs_",""))
epochs = epochs.sort_values(by=['new_id','date_new'])

# %%
#只留running和walking
epochs=epochs[(epochs["activityType"]=="WALKING")|(epochs["activityType"]=="RUNNING")]
epochs
# Out:
#         activeKilocalories  activeTimeInSeconds activityType   date  \
# 27168                  0.0                 60.0      WALKING  927.0
# 27172                  0.0                 60.0      WALKING  927.0
# 27174                  0.0                 60.0      WALKING  927.0
# 27293                  0.0                 15.0      WALKING  927.0
# 27295                 28.0                360.0      WALKING  927.0
# ...                    ...                  ...          ...    ...
# 299453                65.0                864.0      WALKING    NaN
# 299454                41.0                579.0      WALKING    NaN
# 299456                 6.0                 55.0      WALKING    NaN
# 299460                 1.0                 45.0      WALKING    NaN
# 299462                 2.0                 17.0      WALKING    NaN
#
#         distanceInMeters  durationInSeconds      intensity  \
# 27168              10.47              900.0         ACTIVE
# 27172              15.30              900.0         ACTIVE
# 27174               8.05              900.0         ACTIVE
# 27293               7.25              900.0         ACTIVE
# 27295             296.35              900.0         ACTIVE
# ...                  ...                ...            ...
# 299453           1278.08              900.0         ACTIVE
# 299454            710.31              900.0         ACTIVE
# 299456             50.45              900.0         ACTIVE
# 299460             99.30              900.0  HIGHLY_ACTIVE
# 299462             37.64              900.0  HIGHLY_ACTIVE
#
#         maxMotionIntensity  meanMotionIntensity       met                 id  \
# 27168                  2.0             2.000000  1.000000   1091_mr_epochs_1
# 27172                  2.0             2.000000  1.000000   1091_mr_epochs_1
# 27174                  1.0             1.000000  1.000000   1091_mr_epochs_1
# 27293                  2.0             2.000000  1.000000   1091_mr_epochs_1
# 27295                  1.0             1.000000  4.316881   1091_mr_epochs_1
# ...                    ...                  ...       ...                ...
# 299453                 3.0             3.000000  3.869523  1102_mrw_epochs_9
# 299454                 2.0             2.000000  3.700942  1102_mrw_epochs_9
# 299456                 1.0             1.000000  5.161008  1102_mrw_epochs_9
# 299460                 3.0             2.666667  1.847613  1102_mrw_epochs_9
# 299462                 2.0             2.000000  5.487606  1102_mrw_epochs_9
#
#         startTimeInSeconds  startTimeOffsetInSeconds   steps  \
# 27168         1.601077e+09                   28800.0    13.0
# 27172         1.601079e+09                   28800.0    19.0
# 27174         1.601080e+09                   28800.0    10.0
# 27293         1.601186e+09                   28800.0     9.0
# 27295         1.601187e+09                   28800.0   368.0
# ...                    ...                       ...     ...
# 299453        1.653735e+09                   28800.0  1596.0
# 299454        1.653736e+09                   28800.0   887.0
# 299456        1.653736e+09                   28800.0    63.0
# 299460        1.653738e+09                   28800.0   124.0
# 299462        1.653739e+09                   28800.0    47.0
#
#                   summaryId             date_new      new_id
# 27168   x339afaf-5f6e7d78-6  2020-09-26 15:30:00   1091_mr_1
# 27172   x339afaf-5f6e8804-6  2020-09-26 16:15:00   1091_mr_1
# 27174   x339afaf-5f6e8b88-6  2020-09-26 16:30:00   1091_mr_1
# 27293   x339afaf-5f702a60-6  2020-09-27 22:00:00   1091_mr_1
# 27295   x339afaf-5f702de4-6  2020-09-27 22:15:00   1091_mr_1
# ...                     ...                  ...         ...
# 299453  x46bc4c4-6291fd2c-6  2022-05-29 02:45:00  1102_mrw_9
# 299454  x46bc4c4-629200b0-6  2022-05-29 03:00:00  1102_mrw_9
# 299456  x46bc4c4-62920434-6  2022-05-29 03:15:00  1102_mrw_9
# 299460  x46bc4c4-62920b3c-6  2022-05-29 03:45:00  1102_mrw_9
# 299462  x46bc4c4-62920ec0-6  2022-05-29 04:00:00  1102_mrw_9
#
# [76417 rows x 17 columns]

# %%
#算日期
epochs['cut_date_new']=epochs['date_new'].apply(
    lambda x: re.search('\d{4}\-\d{2}\-\d{2}',x).group())
epochs
# Out:
#         activeKilocalories  activeTimeInSeconds activityType   date  \
# 27168                  0.0                 60.0      WALKING  927.0
# 27172                  0.0                 60.0      WALKING  927.0
# 27174                  0.0                 60.0      WALKING  927.0
# 27293                  0.0                 15.0      WALKING  927.0
# 27295                 28.0                360.0      WALKING  927.0
# ...                    ...                  ...          ...    ...
# 299453                65.0                864.0      WALKING    NaN
# 299454                41.0                579.0      WALKING    NaN
# 299456                 6.0                 55.0      WALKING    NaN
# 299460                 1.0                 45.0      WALKING    NaN
# 299462                 2.0                 17.0      WALKING    NaN
#
#         distanceInMeters  durationInSeconds      intensity  \
# 27168              10.47              900.0         ACTIVE
# 27172              15.30              900.0         ACTIVE
# 27174               8.05              900.0         ACTIVE
# 27293               7.25              900.0         ACTIVE
# 27295             296.35              900.0         ACTIVE
# ...                  ...                ...            ...
# 299453           1278.08              900.0         ACTIVE
# 299454            710.31              900.0         ACTIVE
# 299456             50.45              900.0         ACTIVE
# 299460             99.30              900.0  HIGHLY_ACTIVE
# 299462             37.64              900.0  HIGHLY_ACTIVE
#
#         maxMotionIntensity  meanMotionIntensity       met                 id  \
# 27168                  2.0             2.000000  1.000000   1091_mr_epochs_1
# 27172                  2.0             2.000000  1.000000   1091_mr_epochs_1
# 27174                  1.0             1.000000  1.000000   1091_mr_epochs_1
# 27293                  2.0             2.000000  1.000000   1091_mr_epochs_1
# 27295                  1.0             1.000000  4.316881   1091_mr_epochs_1
# ...                    ...                  ...       ...                ...
# 299453                 3.0             3.000000  3.869523  1102_mrw_epochs_9
# 299454                 2.0             2.000000  3.700942  1102_mrw_epochs_9
# 299456                 1.0             1.000000  5.161008  1102_mrw_epochs_9
# 299460                 3.0             2.666667  1.847613  1102_mrw_epochs_9
# 299462                 2.0             2.000000  5.487606  1102_mrw_epochs_9
#
#         startTimeInSeconds  startTimeOffsetInSeconds   steps  \
# 27168         1.601077e+09                   28800.0    13.0
# 27172         1.601079e+09                   28800.0    19.0
# 27174         1.601080e+09                   28800.0    10.0
# 27293         1.601186e+09                   28800.0     9.0
# 27295         1.601187e+09                   28800.0   368.0
# ...                    ...                       ...     ...
# 299453        1.653735e+09                   28800.0  1596.0
# 299454        1.653736e+09                   28800.0   887.0
# 299456        1.653736e+09                   28800.0    63.0
# 299460        1.653738e+09                   28800.0   124.0
# 299462        1.653739e+09                   28800.0    47.0
#
#                   summaryId             date_new      new_id cut_date_new
# 27168   x339afaf-5f6e7d78-6  2020-09-26 15:30:00   1091_mr_1   2020-09-26
# 27172   x339afaf-5f6e8804-6  2020-09-26 16:15:00   1091_mr_1   2020-09-26
# 27174   x339afaf-5f6e8b88-6  2020-09-26 16:30:00   1091_mr_1   2020-09-26
# 27293   x339afaf-5f702a60-6  2020-09-27 22:00:00   1091_mr_1   2020-09-27
# 27295   x339afaf-5f702de4-6  2020-09-27 22:15:00   1091_mr_1   2020-09-27
# ...                     ...                  ...         ...          ...
# 299453  x46bc4c4-6291fd2c-6  2022-05-29 02:45:00  1102_mrw_9   2022-05-29
# 299454  x46bc4c4-629200b0-6  2022-05-29 03:00:00  1102_mrw_9   2022-05-29
# 299456  x46bc4c4-62920434-6  2022-05-29 03:15:00  1102_mrw_9   2022-05-29
# 299460  x46bc4c4-62920b3c-6  2022-05-29 03:45:00  1102_mrw_9   2022-05-29
# 299462  x46bc4c4-62920ec0-6  2022-05-29 04:00:00  1102_mrw_9   2022-05-29
#
# [76417 rows x 18 columns]

# %%
epochs2=epochs[["new_id","cut_date_new","activeTimeInSeconds","activityType"]]
epochs2
# Out:
#             new_id cut_date_new  activeTimeInSeconds activityType
# 27168    1091_mr_1   2020-09-26                 60.0      WALKING
# 27172    1091_mr_1   2020-09-26                 60.0      WALKING
# 27174    1091_mr_1   2020-09-26                 60.0      WALKING
# 27293    1091_mr_1   2020-09-27                 15.0      WALKING
# 27295    1091_mr_1   2020-09-27                360.0      WALKING
# ...            ...          ...                  ...          ...
# 299453  1102_mrw_9   2022-05-29                864.0      WALKING
# 299454  1102_mrw_9   2022-05-29                579.0      WALKING
# 299456  1102_mrw_9   2022-05-29                 55.0      WALKING
# 299460  1102_mrw_9   2022-05-29                 45.0      WALKING
# 299462  1102_mrw_9   2022-05-29                 17.0      WALKING
#
# [76417 rows x 4 columns]

# %%
#分別列出每個人跑步和走路的時間總和
epochs2.groupby(['new_id','cut_date_new','activityType']).sum()
# Out:
#                                       activeTimeInSeconds
# new_id     cut_date_new activityType
# 1091_mr_1  2020-09-26   WALKING                     180.0
#            2020-09-27   WALKING                    1897.0
#            2020-09-28   WALKING                    1143.0
#            2020-09-29   WALKING                    5271.0
#            2020-09-30   RUNNING                     120.0
# ...                                                   ...
# 1102_mrw_9 2022-05-25   WALKING                    1885.0
#            2022-05-26   WALKING                    2201.0
#            2022-05-27   WALKING                    2141.0
#            2022-05-28   WALKING                    1843.0
#            2022-05-29   WALKING                    2101.0
#
# [3766 rows x 1 columns]
